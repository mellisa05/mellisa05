# %% [markdown]
# <a href="https://colab.research.google.com/github/mellisa05/mellisa05/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np
from sklearn.datasets import make_blobs
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
df=pd.read_csv ("https://raw.githubusercontent.com/mellisa05/datasets/main/games.csv")

# %%
df.head()
# Out:
#       Away_Team   Home_Team        Date        Ref_Crew  Accepted_Count  \
# 0     Tennessee  Pittsburgh  09/10/2009      Bill Leavy              11
# 1         Miami     Atlanta  09/13/2009    Walt Coleman               8
# 2   Kansas City   Baltimore  09/13/2009  Gene Steratore              11
# 3  Philadelphia    Carolina  09/13/2009  Jeff Triplette              14
# 4        Denver  Cincinnati  09/13/2009    Jerome Boger              10
#
#    Yards  Away_Count  Away_Yards  Home_Count  Home_Yards  Total_Flags  Week  \
# 0     88           5          28           6          60           13     1
# 1     62           4          27           4          35           11     1
# 2     80           3          15           8          65           14     1
# 3    106           9          76           5          30           14     1
# 4     66           6          39           4          27           12     1
#
#    Year
# 0  2009
# 1  2009
# 2  2009
# 3  2009
# 4  2009

# %%
X, y = make_blobs(n_samples=40, centers=2, random_state=40, cluster_std=1.0)
linkage_matrix = linkage (X, method='ward')

# %%
dendrogram(linkage_matrix, p=5, truncate_mode='level', orientation='top', distance_sort='ascending', show_leaf_counts=True)
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Data Points')
plt.ylabel('Distance')
plt.show()

# %%
num_clusters = 3
clusters = AgglomerativeClustering(n_clusters=num_clusters, affinity='euclidean', linkage='ward').fit_predict(X)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
plt.scatter(X[:, 0], X[:, 1], c=clusters, cmap='viridis', edgecolors='k', s=50)
plt.title('Hierarchical Clustering Result')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
